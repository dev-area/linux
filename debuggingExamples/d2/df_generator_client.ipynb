# %% [markdown]
# ### Bring up the API server using the following

# %% [markdown]
# load docker image using in terminal
# <i/><b/>docker load < df_generator_docker_v1.0.tar.gz</b></i>

# %% [markdown]
# run the docker using <i> <b> docker run df_generator:v1.0 </b> </i>

# %%
import requests
import json
import pandas as pd

# %%
r = requests.post('http://localhost:5802/model/datagenerator_v1.0')
pd.DataFrame(json.loads(r.text))
# Out:
#     feature_1  feature_2  feature_3  feature_4  feature_5
# 0         925        703         55       6499          2
# 1         530        773         11       5801          6
# 2         840        768         56       5174          6
# 3         352        789         88       9639          2
# 4         374        875         24       1040          2
# 5         786        815         94       4913          9
# 6         859        820         57       4076          6
# 7         633        871         43       5432          3
# 8         309        847         69       3045          7
# 9         273        805         51       5871          5
# 10        769        800         92       4722          6
# 11        716        834         75       9064          7
# 12        275        876         89       2342          6
# 13        425        892         61       8326          1
# 14        892        803         35       8887          4
# 15        594        870         65       5884          8
# 16        718        743         44       3742          6
# 17        782        847         41       7861          8
# 18        101        728         35       3103          1
# 19        445        837         79       8578          5
# 20        749        727         31       4435          1
# 21        225        884         79       2061          2
# 22        424        713         89       4298          9
# 23        397        827         26       6452          5
# 24        516        713         59       1933          4
# 25        461        859         71       4222          2
# 26        670        744         59       1946          1
# 27        585        771         18       7137          8
# 28        274        769         15       4398          8
# 29        944        877         72       3863          7
# 30        617        860         74       9929          6
# 31        821        738         89       3947          1
# 32        391        840         55       8137          2
# 33        533        819         94       2117          2
# 34        932        745         80       6948          2
# 35        627        792         48       3870          4
# 36        447        878         89       4833          4
# 37        389        703         71       3487          2
# 38        417        799         70       1347          1
# 39        793        723         62       4799          9
# 40        959        803         52       1610          7
# 41        548        771         14       3044          4
# 42        541        763         34       5135          8
# 43        719        870         10       9572          9
# 44        998        868         89       9586          7
# 45        421        777         90       2014          7
# 46        439        732         88       6523          4
# 47        661        749         13       5848          8
# 48        280        753         18       6304          7
# 49        535        733         71       6147          5
